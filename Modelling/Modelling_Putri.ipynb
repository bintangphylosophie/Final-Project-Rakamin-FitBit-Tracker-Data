# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
train = pd.read_csv('../Dataset/FitbitTrainData.csv')
test = pd.read_csv('../Dataset/FitbitTestData.csv')

# %%
train.sample(10)
# Out:
#      Total_MET  Avg_METs  TrackerDistance  TotalDistance  DistancePerStep  \
# 201  -0.675458 -0.812570        -0.741285      -0.741922         0.380157
# 628  -0.560651 -0.686124        -0.876219      -0.876184        -0.137778
# 638  -1.397714 -1.608051        -1.390970      -1.388368        -3.144916
# 133   0.414995  0.388435        -0.104093      -0.107908         0.061862
# 179  -0.309189 -0.409168        -0.323987      -0.326705         0.060393
# 76   -0.333607 -0.436062         0.083316       0.078567         0.525572
# 118  -0.934631 -1.098019        -1.048636      -1.047741         0.052028
# 310   0.001818 -0.066630         0.028342       0.023868         0.116954
# 351  -1.397714 -1.608051        -1.390970      -1.388368        -3.144916
# 184   1.505448  1.589441         2.529630       2.512686         0.569982
#
#      StepsbyDistance  TotalActiveDistance  TotalSteps  TotalActiveMinutes  \
# 201         0.168451            -0.727781   -0.803866           -1.037728
# 628         0.738761            -0.861974   -0.852758           -0.385821
# 638        -3.142781            -1.373895   -1.490262           -1.887682
# 133         0.497113            -0.091607    0.004278            0.662181
# 179         0.498781            -0.315262   -0.250532            0.084542
# 76          0.037268             0.089802    0.005621            0.257834
# 118         0.508310            -1.033443   -1.091462           -1.169760
# 310         0.435637             0.035131    0.130246            0.365110
# 351        -3.142781            -1.373895   -1.490262           -1.887682
# 184        -0.000747             2.525157    2.440217            0.884985
#
#      ActiveRatio  ...  AveragePace  ActiveGroup  VeryActiveRatio  \
# 201    -1.037728  ...     0.252601    -1.144195        -0.444490
# 628    -0.385821  ...    -0.828570    -1.144195        -0.621244
# 638    -1.887682  ...    -1.707441    -1.144195        -0.621244
# 133     0.662181  ...    -0.413311     0.215183        -0.245642
# 179     0.084542  ...    -0.320176    -0.464506        -0.510773
# 76      0.257834  ...     0.054568     0.215183        -0.444490
# 118    -1.169760  ...    -0.484711    -1.144195        -0.621244
# 310     0.365110  ...    -0.091911     0.215183        -0.510773
# 351    -1.887682  ...    -1.707441    -1.144195        -0.621244
# 184     0.884985  ...     1.918436     1.574561         1.985871
#
#      VeryActiveDistance  FairlyActiveRatio  ActiveDistanceRatio  \
# 201           -0.363502          -0.625238             0.331624
# 628           -0.574141          -0.662279             0.331624
# 638           -0.574141          -0.662279            -3.134234
# 133           -0.363502           0.448966             0.338354
# 179           -0.456326           0.004468             0.323507
# 76            -0.331371          -0.551155             0.325750
# 118           -0.574141          -0.662279             0.331624
# 310           -0.456326           0.078551             0.325522
# 351           -0.574141          -0.662279            -3.134234
# 184            3.485109          -0.328906             0.331624
#
#      FairlyActiveMinutes  TotalUsageMinutes  ModeratelyActiveDistance  \
# 201            -0.637760           0.824493                 -0.582163
# 628            -0.686709           0.098205                 -0.648415
# 638            -0.686709           0.824493                 -0.648415
# 133             0.781777           0.824493                  0.279107
# 179             0.194383           0.824493                  0.257023
# 76             -0.539861           0.824493                 -0.449660
# 118            -0.686709           0.824493                 -0.648415
# 310             0.292282           0.824493                  0.544113
# 351            -0.686709           0.824493                 -0.648415
# 184            -0.246163           0.824493                 -0.140486
#
#      Calories
# 201      2497
# 628      1419
# 638      1841
# 133      2121
# 179      1931
# 76       2771
# 118      1549
# 310      1830
# 351      2063
# 184      3403
#
# [10 rows x 30 columns]

# %% [markdown]
# # Standardization

# %%
# Standarisasi dengan StandardScaler

# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()

# Menentukan kolom numerik untuk distandardisasi
# numerical_cols = train.select_dtypes(include=['float64', 'int64']).columns

# Melakukan fit dan transform pada data train, dan transform pada data test
# train[numerical_cols] = scaler.fit_transform(train[numerical_cols])
# test[numerical_cols] = scaler.transform(test[numerical_cols])

# %%
# Standarisasi dengan Robust Scaler

from sklearn.preprocessing import RobustScaler
import pandas as pd


scaler = RobustScaler()

# Menentukan kolom numerik untuk distandarisasi
numerical_scaled = train.select_dtypes(include=['float64', 'int64']).columns.drop('Calories')

# Melakukan fit dan transform pada data train, dan transform pada data test

train[numerical_scaled] = scaler.fit_transform(train[numerical_scaled])
test[numerical_scaled] = scaler.transform(test[numerical_scaled])

# %%
train.sample(5)
# Out:
#      Total_MET  Avg_METs  TrackerDistance  TotalDistance  DistancePerStep  \
# 443  -0.440126 -0.478594        -0.103314      -0.102913         0.894820
# 246  -0.502451 -0.545149        -0.608187      -0.605825        -0.030832
# 562   0.564076  0.593756         0.259259       0.258252         0.135148
# 609  -0.340861 -0.372593        -0.257310      -0.256311        -0.184729
# 212   0.551471  0.580295         0.732943       0.766990         0.284583
#
#      StepsbyDistance  TotalActiveDistance  TotalSteps  TotalActiveMinutes  \
# 443        -0.560387            -0.094412   -0.170346           -0.077381
# 246         0.227945            -0.593449   -0.595585           -0.333333
# 562         0.072380             0.262042    0.294183            0.601190
# 609         0.378558            -0.248555   -0.205886           -0.184524
# 212        -0.061946             0.747591    0.787589            0.571429
#
#      ActiveRatio  ...  AveragePace  ActiveGroup  VeryActiveRatio  \
# 443    -0.077381  ...    -0.083904    -0.333333        -0.142857
# 246    -0.333333  ...    -0.730748    -0.666667        -0.142857
# 562     0.601190  ...    -0.172180     0.000000         0.976190
# 609    -0.184524  ...    -0.226392    -0.333333        -0.001181
# 212     0.571429  ...     0.399988     0.666667         1.075417
#
#      VeryActiveDistance  FairlyActiveRatio  ActiveDistanceRatio  \
# 443           -0.153488          -0.335417             0.000005
# 246           -0.153488          -0.335417             0.000005
# 562            1.293023          -0.293490            -0.548127
# 609           -0.051163           0.329873            -0.911250
# 212            1.251163           1.564710            -4.325261
#
#      FairlyActiveMinutes  TotalUsageMinutes  ModeratelyActiveDistance  \
# 443                -0.35           0.000000                 -0.329268
# 246                -0.35          -1.013304                 -0.329268
# 562                -0.30           0.000000                 -0.304878
# 609                 0.05          -1.583149                  0.243902
# 212                 1.20          -1.008869                  1.719512
#
#      Calories
# 443      2682
# 246      2113
# 562      2148
# 609      1762
# 212      2194
#
# [5 rows x 30 columns]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data Splitting

# %%
# Data Splitting
X_train = train.drop(columns=['Calories'])
y_train = train['Calories']
X_test = test.drop(columns=['Calories'])
y_test = test['Calories']

# %% [markdown]
# ## Feature Selection with ANOVA

# %%
# Feature Selection with ANOVA

from sklearn.feature_selection import SelectKBest, f_regression
import pandas as pd

selector = SelectKBest(score_func=f_regression, k=10)

# Fit dan transform data train
X_train_selected = selector.fit_transform(X_train, y_train)

# Transform data test dengan fitur yang sama yang dipilih dari data train
X_test_selected = selector.transform(X_test)

# Melihat fitur yang dipilih
selected_features = X_train.columns[selector.get_support()]

selected_features
# Out:
# Index(['Total_MET', 'Avg_METs', 'TrackerDistance', 'TotalDistance',
#        'TotalActiveDistance', 'TotalSteps', 'DistanceIntensity',
#        'VeryActiveMinutes', 'ActiveGroup', 'VeryActiveRatio'],
#       dtype='object')

# %%
X_train= pd.DataFrame(X_train_selected, columns=selected_features)
X_test= pd.DataFrame(X_test_selected, columns=selected_features)

X_train.describe()
# Out:
#         Total_MET    Avg_METs  TrackerDistance  TotalDistance  \
# count  657.000000  657.000000       657.000000     657.000000
# mean    -0.058909   -0.017117         0.048065       0.051263
# std      0.817973    0.793078         0.780699       0.781564
# min     -3.617297   -1.291456        -1.037037      -1.033010
# 25%     -0.566702   -0.534492        -0.530214      -0.528155
# 50%      0.000000    0.000000         0.000000       0.000000
# 75%      0.433298    0.465508         0.469786       0.471845
# max      2.576856    2.743130         4.426901       4.409709
#
#        TotalActiveDistance  TotalSteps  DistanceIntensity  VeryActiveMinutes  \
# count           657.000000  657.000000         657.000000         657.000000
# mean              0.047906    0.028694           0.253983           0.528066
# std               0.775938    0.724646           0.952859           1.036471
# min              -1.017341   -1.050396          -0.682046          -0.151515
# 25%              -0.527938   -0.524226          -0.387161          -0.151515
# 50%               0.000000    0.000000           0.000000           0.000000
# 75%               0.472062    0.475774           0.612839           0.848485
# max               4.381503    3.950160           6.945838           6.212121
#
#        ActiveGroup  VeryActiveRatio
# count   657.000000       657.000000
# mean     -0.105530         0.526618
# std       0.490794         1.078458
# min      -0.666667        -0.142857
# 25%      -0.666667        -0.142857
# 50%       0.000000         0.000000
# 75%       0.333333         0.857143
# max       0.666667         8.418379

# %% [markdown]
# # Evaluation Function

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
from sklearn.model_selection import KFold

def evaluate_model(model, model_name):
    start_time = time.time()
    
    # Inisialisasi K-Fold
    kf = KFold(n_splits=3, shuffle=True, random_state=42)
    
    rmse_train_list = []
    r2_train_list = []
    mae_train_list = []
    mape_train_list = []
    
    # K-Fold Cross Validation
    for train_index, val_index in kf.split(X_train):
        X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
        
        # Latih model pada lipatan
        model.fit(X_train_fold, y_train_fold)
        y_train_pred = model.predict(X_train_fold)
        y_val_pred = model.predict(X_val_fold)
        
        # Hitung metrik untuk lipatan
        rmse_train_list.append(np.sqrt(mean_squared_error(y_train_fold, y_train_pred)))
        r2_train_list.append(r2_score(y_train_fold, y_train_pred))
        mae_train_list.append(mean_absolute_error(y_train_fold, y_train_pred))
        mape_train_list.append(mean_absolute_percentage_error(y_train_fold, y_train_pred))

    # Rata-rata metrik untuk data latih
    rmse_train = np.mean(rmse_train_list)
    r2_train = np.mean(r2_train_list)
    mae_train = np.mean(mae_train_list)
    mape_train = np.mean(mape_train_list)

    # Latih model dengan semua data latih untuk evaluasi
    model.fit(X_train, y_train)
    
    # Hitung prediksi untuk data uji
    y_test_pred = model.predict(X_test)
    
    # Hitung metrik untuk data uji
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    r2_test = r2_score(y_test, y_test_pred)
    mae_test = mean_absolute_error(y_test, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

    # Hitung residual untuk data latih dan data uji
    y_train_pred = model.predict(X_train)  # Prediksi pada seluruh data latih
    residuals_train = y_train - y_train_pred
    residuals_test = y_test - y_test_pred
    mean_residual_train = np.mean(residuals_train)
    mean_residual_test = np.mean(residuals_test)

    # Plot residual
    plt.figure(figsize=(14, 6))

    # Plot residual dan nilai aktual vs prediksi
    plt.figure(figsize=(20, 6))

    # Residuals vs Predicted Values (data latih)
    plt.subplot(1, 3, 1)
    plt.scatter(y_train_pred, residuals_train, color='orange', alpha=0.5)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.title('Residuals vs Predicted Values (Train)')
    plt.xlabel('Predicted Values (Train)')
    plt.ylabel('Residuals (Train)')
    
    # Residuals vs Predicted Values (data uji)
    plt.subplot(1, 3, 2)
    plt.scatter(y_test_pred, residuals_test, color='blue', alpha=0.5)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.title('Residuals vs Predicted Values (Test)')
    plt.xlabel('Predicted Values (Test)')
    plt.ylabel('Residuals (Test)')
    
    # Actual vs Predicted Values (data uji)
    plt.subplot(1, 3, 3)
    plt.scatter(y_test, y_test_pred, color='green', alpha=0.5)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # Garis diagonal
    plt.title('Actual vs Predicted Values (Test)')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')

    plt.tight_layout()
    plt.show()

    end_time = time.time()
    training_time = end_time - start_time

    return {
        'Model': model_name,
        'Training Time (s)': training_time,
        'RMSE Train': rmse_train,
        'RMSE Test': rmse_test,
        'R2 Train': r2_train,
        'R2 Test': r2_test,
        'MAE Train': mae_train,
        'MAE Test': mae_test,
        'Mean Residual Train': mean_residual_train,
        'Mean Residual Test': mean_residual_test,
        'MAPE Train': mape_train,
        'MAPE Test': mape_test
    }

results = []

# %% [markdown]
# # Baseline Modelling

# %% [markdown]
# ## Linear Regression

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression

# Inisialisasi model
model = LinearRegression()

# Evaluasi model
result = evaluate_model(model, "Linear Regression")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Linear Regression', 'Training Time (s)': 0.637598991394043, 'RMSE Train': 324.6489566581914, 'RMSE Test': 376.3549294111469, 'R2 Train': 0.7931228001034301, 'R2 Test': 0.7195954688701207, 'MAE Train': 257.5706155789116, 'MAE Test': 292.12146127170644, 'Mean Residual Train': 1.2147360742857604e-13, 'Mean Residual Test': -24.38942024035227, 'MAPE Train': 1.2082498089999352e+16, 'MAPE Test': 5.649320755497114e+16}

# %% [markdown]
# ## Ridge Regression

# %%
# Ridge Regression
from sklearn.linear_model import Ridge

# Inisialisasi model Ridge Regression
model = Ridge()

# Evaluasi model
result = evaluate_model(model, "Ridge Regression")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Ridge Regression', 'Training Time (s)': 0.6989603042602539, 'RMSE Train': 338.57018677352954, 'RMSE Test': 378.336424777039, 'R2 Train': 0.7749726505714462, 'R2 Test': 0.7166350562595036, 'MAE Train': 277.82244346658536, 'MAE Test': 302.9096397856208, 'Mean Residual Train': 2.595589902320001e-13, 'Mean Residual Test': -15.28788783447964, 'MAPE Train': 1.2241784822647618e+16, 'MAPE Test': 5.724264457906167e+16}

# %% [markdown]
# ## Lasso Regression

# %%
# Lasso Regression
from sklearn.linear_model import Lasso

# Inisialisasi model
model = Lasso()

# Evaluasi model
result = evaluate_model(model, "Lasso Regression")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# c:\Users\putri\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.672e+05, tolerance: 2.288e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\putri\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.283e+05, tolerance: 2.033e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\putri\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.357e+05, tolerance: 2.406e+04
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\putri\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.364e+05, tolerance: 3.365e+04
#   model = cd_fast.enet_coordinate_descent(
# {'Model': 'Lasso Regression', 'Training Time (s)': 0.5852208137512207, 'RMSE Train': 327.280880303095, 'RMSE Test': 379.79600946187713, 'R2 Train': 0.7897011366778132, 'R2 Test': 0.714444450705194, 'MAE Train': 263.330499433983, 'MAE Test': 298.2120074763736, 'Mean Residual Train': 1.5573539413920003e-13, 'Mean Residual Test': -22.89820772518999, 'MAPE Train': 1.2490468719350912e+16, 'MAPE Test': 5.859494279142558e+16}

# %% [markdown]
# ## Decision Tree Regressor

# %%
# Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor

# Inisialisasi model
model = DecisionTreeRegressor()

# Evaluasi model
result = evaluate_model(model, "Decision Tree Regressor")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Decision Tree Regressor', 'Training Time (s)': 0.6871950626373291, 'RMSE Train': 62.761390759849064, 'RMSE Test': 478.5472636560325, 'R2 Train': 0.9923022701330185, 'R2 Test': 0.5466438783490837, 'MAE Train': 13.610337291253686, 'MAE Test': 341.65245343942803, 'Mean Residual Train': 5.191179804640001e-15, 'Mean Residual Test': 4.575534797901176, 'MAPE Train': 97680813835661.44, 'MAPE Test': 910302052340845.0}

# %% [markdown]
# ## K-Nearest Neighbor Regressor

# %%
# KNN
from sklearn.neighbors import KNeighborsRegressor

# Inisialisasi model
model = KNeighborsRegressor()

# Evaluasi model
result = evaluate_model(model, "KNN")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'KNN', 'Training Time (s)': 0.7332851886749268, 'RMSE Train': 360.5559409885961, 'RMSE Test': 437.1787929683651, 'R2 Train': 0.7447799832033085, 'R2 Test': 0.6216375899042852, 'MAE Train': 259.5948249619483, 'MAE Test': 333.64680851063827, 'Mean Residual Train': 4.444140030441396, 'Mean Residual Test': 39.33049645390071, 'MAPE Train': 1.0031990950771264e+16, 'MAPE Test': 3.7657758586310744e+16}

# %% [markdown]
# ## Support Vector Regressor

# %%
# SVR
from sklearn.svm import SVR

# Inisialisasi model
model = SVR()

# Evaluasi model
result = evaluate_model(model, "SVR")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'SVR', 'Training Time (s)': 0.9708318710327148, 'RMSE Train': 712.6206447630337, 'RMSE Test': 703.1746945304573, 'R2 Train': 0.00626740658642122, 'R2 Test': 0.021149704608889097, 'MAE Train': 541.3074968004603, 'MAE Test': 534.6304260378168, 'Mean Residual Train': 169.28539683774082, 'Mean Residual Test': 162.31899418010312, 'MAPE Train': 1.457450105909049e+16, 'MAPE Test': 6.672594871331489e+16}

# %% [markdown]
# ## Random Forest Regressor

# %%
# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# Inisialisasi model
model = RandomForestRegressor()

# Evaluasi model
result = evaluate_model(model, "Random Forest Regressor")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Random Forest Regressor', 'Training Time (s)': 2.8649168014526367, 'RMSE Train': 161.4762330298801, 'RMSE Test': 371.6328747575515, 'R2 Train': 0.948597771438256, 'R2 Test': 0.7265876929226947, 'MAE Train': 120.46690590859663, 'MAE Test': 288.22167120810394, 'Mean Residual Train': 4.5306054567573435, 'Mean Residual Test': 45.44024128230687, 'MAPE Train': 2985601711776469.0, 'MAPE Test': 1.0078161634214272e+16}

# %% [markdown]
# ## Gradient Boosting Regressor

# %%
# Gradient Boosting Regressor
from sklearn.ensemble import GradientBoostingRegressor

# Inisialisasi model
model = GradientBoostingRegressor()

# Evaluasi model
result = evaluate_model(model, "Gradient Boost Regressor")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Gradient Boost Regressor', 'Training Time (s)': 1.7542407512664795, 'RMSE Train': 222.8504015631937, 'RMSE Test': 373.76547752158956, 'R2 Train': 0.9026145234855311, 'R2 Test': 0.7234407547826488, 'MAE Train': 181.2498291360673, 'MAE Test': 300.63220482742884, 'Mean Residual Train': -2.090315068001707e-13, 'Mean Residual Test': 38.72115611919618, 'MAPE Train': 1860855622823170.8, 'MAPE Test': 1.2044444097278256e+16}

# %% [markdown]
# ## Hasil setelah Baseline Modelling

# %%
results_df = pd.DataFrame(results)

results_df['RMSE Difference'] = results_df['RMSE Test'] - results_df['RMSE Train']
results_df['R2 Difference'] = results_df['R2 Test'] - results_df['R2 Train']
results_df['MAE Difference'] = results_df['MAE Test'] - results_df['MAE Train']
results_df['MAPE Difference'] = results_df['MAPE Test'] - results_df['MAPE Train']

# Menentukan urutan kolom yang diinginkan
columns_order = [
    'Model', 'Training Time (s)', 
    'RMSE Train', 'RMSE Test', 'RMSE Difference',
    'R2 Train', 'R2 Test', 'R2 Difference',
    'MAE Train', 'MAE Test', 'MAE Difference',
    'Mean Residual Train', 'Mean Residual Test',
    'MAPE Train', 'MAPE Test', 'MAPE Difference'
]

# Mengatur urutan kolom dan mengurutkan hasil berdasarkan beberapa metrik
results_df = results_df[columns_order].sort_values(
    by=['RMSE Test', 'RMSE Train', 'RMSE Difference'],
    ascending=[True, True, True]
)

# Tampilkan DataFrame hasil
results_df
# Out:
#                       Model  Training Time (s)  RMSE Train   RMSE Test  \
# 6   Random Forest Regressor           2.864917  161.476233  371.632875
# 7  Gradient Boost Regressor           1.754241  222.850402  373.765478
# 0         Linear Regression           0.637599  324.648957  376.354929
# 1          Ridge Regression           0.698960  338.570187  378.336425
# 2          Lasso Regression           0.585221  327.280880  379.796009
# 4                       KNN           0.733285  360.555941  437.178793
# 3   Decision Tree Regressor           0.687195   62.761391  478.547264
# 5                       SVR           0.970832  712.620645  703.174695
#
#    RMSE Difference  R2 Train   R2 Test  R2 Difference   MAE Train    MAE Test  \
# 6       210.156642  0.948598  0.726588      -0.222010  120.466906  288.221671
# 7       150.915076  0.902615  0.723441      -0.179174  181.249829  300.632205
# 0        51.705973  0.793123  0.719595      -0.073527  257.570616  292.121461
# 1        39.766238  0.774973  0.716635      -0.058338  277.822443  302.909640
# 2        52.515129  0.789701  0.714444      -0.075257  263.330499  298.212007
# 4        76.622852  0.744780  0.621638      -0.123142  259.594825  333.646809
# 3       415.785873  0.992302  0.546644      -0.445658   13.610337  341.652453
# 5        -9.445950  0.006267  0.021150       0.014882  541.307497  534.630426
#
#    MAE Difference  Mean Residual Train  Mean Residual Test    MAPE Train  \
# 6      167.754765         4.530605e+00           45.440241  2.985602e+15
# 7      119.382376        -2.090315e-13           38.721156  1.860856e+15
# 0       34.550846         1.214736e-13          -24.389420  1.208250e+16
# 1       25.087196         2.595590e-13          -15.287888  1.224178e+16
# 2       34.881508         1.557354e-13          -22.898208  1.249047e+16
# 4       74.051984         4.444140e+00           39.330496  1.003199e+16
# 3      328.042116         5.191180e-15            4.575535  9.768081e+13
# 5       -6.677071         1.692854e+02          162.318994  1.457450e+16
#
#       MAPE Test  MAPE Difference
# 6  1.007816e+16     7.092560e+15
# 7  1.204444e+16     1.018359e+16
# 0  5.649321e+16     4.441071e+16
# 1  5.724264e+16     4.500086e+16
# 2  5.859494e+16     4.610447e+16
# 4  3.765776e+16     2.762577e+16
# 3  9.103021e+14     8.126212e+14
# 5  6.672595e+16     5.215145e+16

# %% [markdown]
# # Tuning Modelling

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Grid Search

# %%
# Random Forest with Tuning dengan Grid Search
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Set Hyperparameter
rf_params = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2',None]
}
# Inisialisasi Model dengan Tuning
rf_model = GridSearchCV(RandomForestRegressor(), rf_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_jobs=-1)
rf_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(rf_model.best_estimator_, 'Random Forest Grid Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# {'Model': 'Random Forest Grid Search', 'Training Time (s)': 2.3755595684051514, 'RMSE Train': 159.78636865703203, 'RMSE Test': 361.8272663001107, 'R2 Train': 0.9498471606061663, 'R2 Test': 0.7408254269323157, 'MAE Train': 120.31723670709947, 'MAE Test': 281.46859327640254, 'Mean Residual Train': 5.966733125000458, 'Mean Residual Test': 38.65535536005832, 'MAPE Train': 2907105630110794.5, 'MAPE Test': 1.0249857377454914e+16}

# %% [markdown]
# ### Bayesian Optimization

# %%
# Random Forest with Tuning dengan Bayesian Optimization
from skopt import BayesSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Set Hyperparameter
rf_params = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2',None]
}
# Inisialisasi Model dengan Tuning
rf_model = BayesSearchCV(RandomForestRegressor(), rf_params, scoring='neg_mean_absolute_error', cv=5, n_iter=30,verbose=2, n_jobs=-1)
rf_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(rf_model.best_estimator_, 'Random Forest Bayes Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [30, None, 4, 10]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [None, 'log2', 2, 10]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [20, 'log2', 1, 10]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [None, None, 1, 10]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [10, None, 2, 5]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [None, 'log2', 1, 10]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [None, None, 4, 10]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [30, 'log2', 4, 5]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [20, 'log2', 4, 10]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [10, 'log2', 2, 10]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [None, None, 2, 10]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [20, 'sqrt', 1, 2]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [20, None, 1, 5] before, using random point [10, None, 4, 2]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# {'Model': 'Random Forest Bayes Search', 'Training Time (s)': 2.348792552947998, 'RMSE Train': 187.90201425160498, 'RMSE Test': 374.9515446063101, 'R2 Train': 0.9306017193197088, 'R2 Test': 0.7216827632843343, 'MAE Train': 141.7696773256885, 'MAE Test': 294.1101012494088, 'Mean Residual Train': 4.9732119780921495, 'Mean Residual Test': 41.72522114531507, 'MAPE Train': 3715054439697386.5, 'MAPE Test': 2.0655910900952668e+16}

# %% [markdown]
# ## Gradient Boost Regressor

# %% [markdown]
# ### Grid Search

# %%
# Gradient Boost with Tuning dengan Grid Search
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# Set Hyperparameter
gb_params = {
    'n_estimators': [100, 200], 
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5]
}
# Inisialisasi Model dengan Tuning
gb_model = GridSearchCV(GradientBoostingRegressor(), gb_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_jobs=-1)
gb_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(gb_model.best_estimator_, 'Gradient Boost Grid Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# {'Model': 'Gradient Boost Grid Search', 'Training Time (s)': 2.483834743499756, 'RMSE Train': 148.39377735758873, 'RMSE Test': 359.2276896621242, 'R2 Train': 0.9568344945041526, 'R2 Test': 0.7445361692875063, 'MAE Train': 115.59402584758239, 'MAE Test': 281.2649171216443, 'Mean Residual Train': 1.2458831531136003e-14, 'Mean Residual Test': 43.364959717261556, 'MAPE Train': 1129982143215163.8, 'MAPE Test': 4686631285430838.0}

# %% [markdown]
# ### Bayesian Optimization

# %%
# Gradient Boost with Tuning dengan Bayesian Optimization
from skopt import BayesSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Set Hyperparameter
gb_params = {
    'n_estimators': [100, 200], 
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5]
}
# Inisialisasi Model dengan Tuning
gb_model = BayesSearchCV(GradientBoostingRegressor(), gb_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_iter=30, n_jobs=-1)
gb_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(rf_model.best_estimator_, 'Gradient Boost Bayes Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.09239444809296497, 3, 116]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.04036592696130722, 4, 134]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.032307676060322886, 5, 103]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.019603344242735014, 4, 150]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.046631345505175205, 4, 190]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.05410861831697059, 4, 153]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.08932910288501424, 5, 126]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.04234149159089113, 3, 144]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.097108392157858, 3, 169]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 4, 200] before, using random point [0.09371616018872754, 3, 197]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# {'Model': 'Gradient Boost Bayes Search', 'Training Time (s)': 2.203775405883789, 'RMSE Train': 188.3246156448255, 'RMSE Test': 369.06891277362917, 'R2 Train': 0.9303048596258937, 'R2 Test': 0.7303473201329422, 'MAE Train': 141.5715610076051, 'MAE Test': 290.045782674839, 'Mean Residual Train': 2.383738430500877, 'Mean Residual Test': 44.09078723171619, 'MAPE Train': 4451488521790710.5, 'MAPE Test': 1.630844075032961e+16}

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# ### Grid Search

# %%
# Ridge Regression with Tuning dengan Grid Search
from sklearn.linear_model import Ridge

# Set Hyperparameter
ridge_params = {
    'alpha': [0.1, 1.0, 10.0],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'saga'] 
}

# Inisialisasi Model dengan Tuning
ridge_model = GridSearchCV(Ridge(), ridge_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_jobs=-1)
ridge_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(ridge_model.best_estimator_, 'Ridge Grid Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# {'Model': 'Ridge Grid Search', 'Training Time (s)': 0.7030041217803955, 'RMSE Train': 325.1282643500806, 'RMSE Test': 375.66643331334126, 'R2 Train': 0.7925008793440015, 'R2 Test': 0.7206204632184956, 'MAE Train': 259.64235788970683, 'MAE Test': 292.9607534916809, 'Mean Residual Train': -8.409711283516802e-14, 'Mean Residual Test': -23.459283578578756, 'MAPE Train': 1.2084828090065982e+16, 'MAPE Test': 5.656209914770741e+16}

# %% [markdown]
# ### Bayesian Optimization

# %%
# Ridge Regression with Tuning dengan Bayesian Optimization
from skopt import BayesSearchCV
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error

# Set Hyperparameter
ridge_params = {
    'alpha': [0.1, 1.0, 10.0],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'saga'] 
}

# Inisialisasi Model dengan Tuning
ridge_model = BayesSearchCV(Ridge(), ridge_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_iter= 30, n_jobs=-1)
ridge_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(rf_model.best_estimator_, 'Ridge Bayes Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'svd'] before, using random point [0.1, 'svd']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [0.1, 'svd']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [0.1, 'cholesky']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [1.0, 'svd']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [10.0, 'lsqr']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [10.0, 'saga']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [10.0, 'auto']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [0.1, 'auto']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [1.0, 'lsqr']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [10.0, 'lsqr']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [10.0, 'saga']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [0.1, 'auto']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [10.0, 'lsqr']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [0.1, 'auto']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [1.0, 'svd']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [1.0, 'saga']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [10.0, 'lsqr']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# {'Model': 'Ridge Bayes Search', 'Training Time (s)': 2.281935930252075, 'RMSE Train': 185.67524645915077, 'RMSE Test': 373.78966547816424, 'R2 Train': 0.9323221357950261, 'R2 Test': 0.7234049589702165, 'MAE Train': 140.30492964847397, 'MAE Test': 292.02357271818505, 'Mean Residual Train': 4.1116346810064375, 'Mean Residual Test': 39.8260287049412, 'MAPE Train': 4061814104326057.5, 'MAPE Test': 1.7910916482481816e+16}

# %% [markdown]
# ## CatBoost

# %% [markdown]
# ### GridSearch

# %%
# CatBoost with Tuning dengan GridSearch
from catboost import CatBoostRegressor
from sklearn.model_selection import GridSearchCV

# Set Hyperparameter
cat_params = {
    'depth': [None, 6, 8], 
    'iterations': [100, 200],
    'learning_rate': [0.01, 0.1],
    'l2_leaf_reg': [3, 5] 
}

# Inisialisasi model dengan Tuning
cat_model = GridSearchCV(CatBoostRegressor(silent=True), cat_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_jobs=-1)
cat_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(cat_model.best_estimator_, 'CatBoost GridSearch')
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# {'Model': 'CatBoost GridSearch', 'Training Time (s)': 5.71781063079834, 'RMSE Train': 172.23935758892262, 'RMSE Test': 362.5170419330208, 'R2 Train': 0.9417161030377087, 'R2 Test': 0.7398363212199062, 'MAE Train': 136.63275904541277, 'MAE Test': 287.60759757138675, 'Mean Residual Train': 0.37567101238528333, 'Mean Residual Test': 37.236202679754314, 'MAPE Train': 1567299668447282.0, 'MAPE Test': 8246922925799322.0}

# %% [markdown]
# ### Bayesian Optimization

# %%
# Set Hyperparameter
cat_params = {
    'depth': [None, 6, 8], 
    'iterations': [100, 200],
    'learning_rate': [0.01, 0.1],
    'l2_leaf_reg': [3, 5] 
}

# Inisialisasi model dengan Tuning
cat_model = BayesSearchCV(CatBoostRegressor(silent=True), cat_params, scoring='neg_mean_absolute_error', cv=5,n_iter=30, verbose=2, n_jobs=-1)
cat_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(cat_model.best_estimator_, 'CatBoost BayesSearch')
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [None, 200, 3, 0.1] before, using random point [None, 195, 5, 0.05490239957733139]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [None, 200, 3, 0.1] before, using random point [8, 144, 5, 0.03841660338677248]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [8, 200, 3, 0.1] before, using random point [8, 189, 4, 0.09074048330956333]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [8, 200, 3, 0.1] before, using random point [6, 165, 5, 0.08299423667024543]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [None, 200, 3, 0.1] before, using random point [6, 167, 3, 0.03806877317119248]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [None, 200, 3, 0.1] before, using random point [8, 173, 5, 0.010285879358297178]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [8, 200, 3, 0.1] before, using random point [8, 115, 4, 0.03228753376629512]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [8, 200, 3, 0.1] before, using random point [8, 147, 4, 0.0105373941379492]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [8, 200, 3, 0.1] before, using random point [6, 116, 4, 0.060204736963509704]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [8, 200, 3, 0.1] before, using random point [8, 128, 3, 0.05333966823454913]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [8, 200, 3, 0.1] before, using random point [6, 157, 3, 0.02669596176959474]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [8, 200, 3, 0.1] before, using random point [8, 161, 4, 0.09112181818637849]
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# {'Model': 'CatBoost BayesSearch', 'Training Time (s)': 5.780231714248657, 'RMSE Train': 172.23935758892262, 'RMSE Test': 362.5170419330208, 'R2 Train': 0.9417161030377087, 'R2 Test': 0.7398363212199062, 'MAE Train': 136.63275904541277, 'MAE Test': 287.60759757138675, 'Mean Residual Train': 0.37567101238528333, 'Mean Residual Test': 37.236202679754314, 'MAPE Train': 1567299668447282.0, 'MAPE Test': 8246922925799322.0}

# %% [markdown]
# ## XG Boost

# %% [markdown]
# ### GridSearch

# %%
# XG Boost with Tuning dengan GridSearch
import xgboost as xgb
from xgboost import XGBRegressor


# Set Hyperparameter
xgb_params = { 'n_estimators': [50, 100],        
    'max_depth': [3, 5],               
    'learning_rate': [0.01, 0.1, 0.2], 
    'subsample': [0.8, 1.0] 
    }

# Inisialisasi Model 
xgb_model = GridSearchCV(XGBRegressor(), xgb_params, scoring='neg_mean_absolute_error',cv=5)
xgb_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(xgb_model.best_estimator_, 'XG Boost GridSearch')
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'XG Boost GridSearch', 'Training Time (s)': 1.484025239944458, 'RMSE Train': 85.27937399928857, 'RMSE Test': 361.5890066533001, 'R2 Train': 0.9857599587793778, 'R2 Test': 0.7411666422957441, 'MAE Train': 54.28056392060023, 'MAE Test': 274.6556576667948, 'Mean Residual Train': 1.2045545418331431, 'Mean Residual Test': 30.937396272699882, 'MAPE Train': 300586247580704.75, 'MAPE Test': 1773360439170040.8}

# %% [markdown]
# ### Bayesian Optimization

# %%
# XG Boost with Tuning dengan GridSearch
import xgboost as xgb
from xgboost import XGBRegressor

# Set Hyperparameter
xgb_params = { 'n_estimators': [50, 100],        
    'max_depth': [3, 5],               
    'learning_rate': [0.01, 0.1, 0.2], 
    'subsample': [0.8, 1.0] 
    }

# Inisialisasi Model 
xgb_model = BayesSearchCV(XGBRegressor(), xgb_params, scoring='neg_mean_absolute_error',n_iter=30,cv=5)
xgb_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(xgb_model.best_estimator_, 'XG Boost BayesSearch')
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [50, 100] was inferred to Integer(low=50, high=100, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(50, 100), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.8, 1.0] was inferred to Real(low=0.8, high=1.0, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.8, 1.0), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [50, 100] was inferred to Integer(low=50, high=100, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(50, 100), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.8, 1.0] was inferred to Real(low=0.8, high=1.0, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.8, 1.0), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [50, 100] was inferred to Integer(low=50, high=100, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(50, 100), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.8, 1.0] was inferred to Real(low=0.8, high=1.0, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.8, 1.0), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.01, 5, 100, 0.8] before, using random point [0.01, 4, 95, 0.934353039853309]
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 5, 100, 0.8] before, using random point [0.01, 4, 95, 0.8109483351045852]
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 5, 100, 0.8] before, using random point [0.01, 4, 91, 0.9801734072522351]
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 5, 99, 0.8] before, using random point [0.2, 3, 74, 0.9084678753120876]
#   warnings.warn(
# {'Model': 'XG Boost BayesSearch', 'Training Time (s)': 1.4691944122314453, 'RMSE Train': 85.27937399928857, 'RMSE Test': 361.5890066533001, 'R2 Train': 0.9857599587793778, 'R2 Test': 0.7411666422957441, 'MAE Train': 54.28056392060023, 'MAE Test': 274.6556576667948, 'Mean Residual Train': 1.2045545418331431, 'Mean Residual Test': 30.937396272699882, 'MAPE Train': 300586247580704.75, 'MAPE Test': 1773360439170040.8}

# %% [markdown]
# ## Hasil Setelah Tuning Modelling

# %%
results_df = pd.DataFrame(results)

results_df['RMSE Difference'] = results_df['RMSE Test'] - results_df['RMSE Train']
results_df['R2 Difference'] = results_df['R2 Test'] - results_df['R2 Train']
results_df['MAE Difference'] = results_df['MAE Test'] - results_df['MAE Train']
results_df['MAPE Difference'] = results_df['MAPE Test'] - results_df['MAPE Train']

results_df = results_df[columns_order].sort_values(by=['RMSE Test','RMSE Train','RMSE Difference'],ascending=[True,True,True])

results_df
# Out:
#                           Model  Training Time (s)  RMSE Train   RMSE Test  \
# 10   Gradient Boost Grid Search           2.483835  148.393777  359.227690
# 16          XG Boost GridSearch           1.484025   85.279374  361.589007
# 17         XG Boost BayesSearch           1.469194   85.279374  361.589007
# 8     Random Forest Grid Search           2.375560  159.786369  361.827266
# 14          CatBoost GridSearch           5.717811  172.239358  362.517042
# 15         CatBoost BayesSearch           5.780232  172.239358  362.517042
# 11  Gradient Boost Bayes Search           2.203775  188.324616  369.068913
# 6       Random Forest Regressor           2.864917  161.476233  371.632875
# 7      Gradient Boost Regressor           1.754241  222.850402  373.765478
# 13           Ridge Bayes Search           2.281936  185.675246  373.789665
# 9    Random Forest Bayes Search           2.348793  187.902014  374.951545
# 12            Ridge Grid Search           0.703004  325.128264  375.666433
# 0             Linear Regression           0.637599  324.648957  376.354929
# 1              Ridge Regression           0.698960  338.570187  378.336425
# 2              Lasso Regression           0.585221  327.280880  379.796009
# 4                           KNN           0.733285  360.555941  437.178793
# 3       Decision Tree Regressor           0.687195   62.761391  478.547264
# 5                           SVR           0.970832  712.620645  703.174695
#
#     RMSE Difference  R2 Train   R2 Test  R2 Difference   MAE Train  \
# 10       210.833912  0.956834  0.744536      -0.212298  115.594026
# 16       276.309633  0.985760  0.741167      -0.244593   54.280564
# 17       276.309633  0.985760  0.741167      -0.244593   54.280564
# 8        202.040898  0.949847  0.740825      -0.209022  120.317237
# 14       190.277684  0.941716  0.739836      -0.201880  136.632759
# 15       190.277684  0.941716  0.739836      -0.201880  136.632759
# 11       180.744297  0.930305  0.730347      -0.199958  141.571561
# 6        210.156642  0.948598  0.726588      -0.222010  120.466906
# 7        150.915076  0.902615  0.723441      -0.179174  181.249829
# 13       188.114419  0.932322  0.723405      -0.208917  140.304930
# 9        187.049530  0.930602  0.721683      -0.208919  141.769677
# 12        50.538169  0.792501  0.720620      -0.071880  259.642358
# 0         51.705973  0.793123  0.719595      -0.073527  257.570616
# 1         39.766238  0.774973  0.716635      -0.058338  277.822443
# 2         52.515129  0.789701  0.714444      -0.075257  263.330499
# 4         76.622852  0.744780  0.621638      -0.123142  259.594825
# 3        415.785873  0.992302  0.546644      -0.445658   13.610337
# 5         -9.445950  0.006267  0.021150       0.014882  541.307497
#
#       MAE Test  MAE Difference  Mean Residual Train  Mean Residual Test  \
# 10  281.264917      165.670891         1.245883e-14           43.364960
# 16  274.655658      220.375094         1.204555e+00           30.937396
# 17  274.655658      220.375094         1.204555e+00           30.937396
# 8   281.468593      161.151357         5.966733e+00           38.655355
# 14  287.607598      150.974839         3.756710e-01           37.236203
# 15  287.607598      150.974839         3.756710e-01           37.236203
# 11  290.045783      148.474222         2.383738e+00           44.090787
# 6   288.221671      167.754765         4.530605e+00           45.440241
# 7   300.632205      119.382376        -2.090315e-13           38.721156
# 13  292.023573      151.718643         4.111635e+00           39.826029
# 9   294.110101      152.340424         4.973212e+00           41.725221
# 12  292.960753       33.318396        -8.409711e-14          -23.459284
# 0   292.121461       34.550846         1.214736e-13          -24.389420
# 1   302.909640       25.087196         2.595590e-13          -15.287888
# 2   298.212007       34.881508         1.557354e-13          -22.898208
# 4   333.646809       74.051984         4.444140e+00           39.330496
# 3   341.652453      328.042116         5.191180e-15            4.575535
# 5   534.630426       -6.677071         1.692854e+02          162.318994
#
#       MAPE Train     MAPE Test  MAPE Difference
# 10  1.129982e+15  4.686631e+15     3.556649e+15
# 16  3.005862e+14  1.773360e+15     1.472774e+15
# 17  3.005862e+14  1.773360e+15     1.472774e+15
# 8   2.907106e+15  1.024986e+16     7.342752e+15
# 14  1.567300e+15  8.246923e+15     6.679623e+15
# 15  1.567300e+15  8.246923e+15     6.679623e+15
# 11  4.451489e+15  1.630844e+16     1.185695e+16
# 6   2.985602e+15  1.007816e+16     7.092560e+15
# 7   1.860856e+15  1.204444e+16     1.018359e+16
# 13  4.061814e+15  1.791092e+16     1.384910e+16
# 9   3.715054e+15  2.065591e+16     1.694086e+16
# 12  1.208483e+16  5.656210e+16     4.447727e+16
# 0   1.208250e+16  5.649321e+16     4.441071e+16
# 1   1.224178e+16  5.724264e+16     4.500086e+16
# 2   1.249047e+16  5.859494e+16     4.610447e+16
# 4   1.003199e+16  3.765776e+16     2.762577e+16
# 3   9.768081e+13  9.103021e+14     8.126212e+14
# 5   1.457450e+16  6.672595e+16     5.215145e+16
