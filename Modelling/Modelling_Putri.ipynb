# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
train = pd.read_csv('../Dataset/FitbitTrainData.csv')
test = pd.read_csv('../Dataset/FitbitTestData.csv')

# %%
train.sample(10)
# Out:
#      Total_MET   Avg_METs  TotalDistance  DistancePerStep  TrackerDistance  \
# 318    17982.0  12.487500           2.42         0.000674             2.42
# 336    14400.0  10.000000           0.00         0.000000             0.00
# 17     24784.0  17.211111           6.65         0.000793             6.65
# 410    22115.0  15.357639           6.47         0.000671             6.47
# 237    24915.0  17.302083           8.43         0.000719             8.43
# 396    21532.0  14.952778           5.54         0.000672             5.54
# 297    16874.0  11.718056           1.84         0.000651             1.84
# 4      26431.0  18.354861           6.08         0.000747             6.08
# 233    24903.0  17.293750          11.90         0.000769            11.90
# 426    21556.0  14.969444           5.32         0.000673             5.32
#
#      StepsbyDistance  TotalActiveDistance  TotalSteps  ActiveRatio  \
# 318      1482.644581                 2.42        3588     0.111111
# 336         0.000000                 0.00           0     0.000000
# 17       1260.451110                 6.65        8382     0.177083
# 410      1491.190157                 6.48        9648     0.222917
# 237      1391.221776                 8.34       11728     0.191667
# 396      1487.725642                 5.54        8242     0.219444
# 297      1535.869537                 1.83        2826     0.097222
# 4        1337.993438                 6.08        8135     0.168056
# 233      1301.176512                11.91       15484     0.190278
# 426      1486.842057                 5.32        7910     0.229861
#
#      AverageActiveMinutes  ...  AveragePace  ActiveGroup  VeryActiveRatio  \
# 318             53.333333  ...     0.907500            0         0.002083
# 336              0.000000  ...     0.000000            0         0.000000
# 17              85.000000  ...     1.564706            2         0.069133
# 410            107.000000  ...     1.209346            2         0.008081
# 237             92.000000  ...     1.832609            3         0.031879
# 396            105.333333  ...     1.051899            2         0.001389
# 297             46.666667  ...     0.788571            0         0.000000
# 4               80.666667  ...     1.507438            2         0.088660
# 233             91.333333  ...     2.605839            4         0.060417
# 426            110.333333  ...     0.964350            2         0.000000
#
#      VeryActiveDistance  FairlyActiveRatio  ActiveDistanceRatio  \
# 318                0.23           0.003472             1.000000
# 336                0.00           0.000000             0.000000
# 17                 1.27           0.012658             1.000000
# 410                0.58           0.026263             1.001546
# 237                2.62           0.035235             0.989324
# 396                0.12           0.003472             1.000000
# 297                0.00           0.000000             0.994565
# 4                  3.60           0.016495             1.000000
# 233                8.39           0.015278             1.000840
# 426                0.00           0.000000             1.000000
#
#      FairlyActiveMinutes  TotalUsageMinutes  ModeratelyActiveDistance  \
# 318                    5               1440                      0.20
# 336                    0               1440                      0.00
# 17                    13               1027                      0.66
# 410                   26                990                      1.07
# 237                   42               1192                      1.68
# 396                    5               1440                      0.18
# 297                    0               1440                      0.00
# 4                     16                970                      0.38
# 233                   22               1440                      0.93
# 426                    0               1440                      0.00
#
#      Calories
# 318      1654
# 336      2063
# 17       3721
# 410      2235
# 237      3429
# 396      1882
# 297      1402
# 4        3405
# 233      3023
# 426      1893
#
# [10 rows x 30 columns]

# %% [markdown]
# # Standardization with StandardScaler

# %%
# Standarisasi dengan StandardScaler

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Menentukan kolom numerik untuk distandardisasi
numerical_cols = train.select_dtypes(include=['float64', 'int64']).columns

# Melakukan fit dan transform pada data train, dan transform pada data test
train[numerical_cols] = scaler.fit_transform(train[numerical_cols])
test[numerical_cols] = scaler.transform(test[numerical_cols])

# %%
train.sample(5)
# Out:
#      Total_MET  Avg_METs  TotalDistance  DistancePerStep  TrackerDistance  \
# 456   1.287400  1.349287       1.015914         0.702281         1.025359
# 502  -1.397714 -1.608051      -1.388368        -3.144916        -1.390970
# 528  -0.483970 -0.601669      -0.637496         0.112492        -0.636335
# 483  -1.397714 -1.608051      -1.388368        -3.144916        -1.390970
# 560   1.997233  2.131085       3.149187         1.234645         3.169320
#
#      StepsbyDistance  TotalActiveDistance  TotalSteps  ActiveRatio  \
# 456        -0.108797             1.031639    0.848852     0.455881
# 502        -3.142781            -1.373895   -1.490262    -1.887682
# 528         0.440538            -0.623409   -0.627474    -0.270293
# 483        -3.142781            -1.373895   -1.490262    -1.887682
# 560        -0.477598             3.133996    2.387683     0.662181
#
#      AverageActiveMinutes  ...  AveragePace  ActiveGroup  VeryActiveRatio  \
# 456              0.455881  ...     0.936413     0.894872         2.792970
# 502             -1.887682  ...    -1.707441    -1.144195        -0.621244
# 528             -0.270293  ...    -0.511031    -1.144195        -0.586088
# 483             -1.887682  ...    -1.707441    -1.144195        -0.621244
# 560              0.662181  ...     2.878556     1.574561         0.991632
#
#      VeryActiveDistance  FairlyActiveRatio  ActiveDistanceRatio  \
# 456            1.178798          -0.054419             0.335208
# 502           -0.574141          -0.662279            -3.134234
# 528           -0.552720           0.457561             0.331624
# 483           -0.574141          -0.662279            -3.134234
# 560            3.388716           0.041509             0.310734
#
#      FairlyActiveMinutes  TotalUsageMinutes  ModeratelyActiveDistance  \
# 456            -0.099315          -0.609554                  0.003059
# 502            -0.686709           0.824493                 -0.648415
# 528             0.243332          -1.157975                  0.245981
# 483            -0.686709           0.824493                 -0.648415
# 560             0.243332           0.824493                  0.234939
#
#      Calories
# 456  2.423679
# 502 -0.348500
# 528 -0.591625
# 483 -0.868284
# 560  1.956992
#
# [5 rows x 30 columns]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data Splitting

# %%
# Data Splitting
X_train = train.drop(columns=['Calories'])
y_train = train['Calories']
X_test = test.drop(columns=['Calories'])
y_test = test['Calories']

# %% [markdown]
# ## Feature Selection with ANOVA

# %%
# Feature Selection with ANOVA

from sklearn.feature_selection import SelectKBest, f_regression
import pandas as pd

selector = SelectKBest(score_func=f_regression, k=15)

# Fit dan transform data train
X_train_selected = selector.fit_transform(X_train, y_train)

# Transform data test dengan fitur yang sama yang dipilih dari data train
X_test_selected = selector.transform(X_test)

# Melihat fitur yang dipilih
selected_features = X_train.columns[selector.get_support()]

selected_features
# Out:
# Index(['Total_MET', 'Avg_METs', 'TotalDistance', 'TrackerDistance',
#        'TotalActiveDistance', 'TotalSteps', 'AverageActiveMinutes',
#        'TotalActiveMinutes', 'DistanceIntensity', 'ActivityRank',
#        'VeryActiveMinutes', 'AveragePace', 'ActiveGroup', 'VeryActiveRatio',
#        'VeryActiveDistance'],
#       dtype='object')

# %%
X_train= pd.DataFrame(X_train_selected, columns=selected_features)
X_test= pd.DataFrame(X_test_selected, columns=selected_features)

X_train.describe()
# Out:
#           Total_MET      Avg_METs  TotalDistance  TrackerDistance  \
# count  6.570000e+02  6.570000e+02   6.570000e+02     6.570000e+02
# mean   4.596357e-17  1.622244e-16  -2.433366e-17     3.312081e-17
# std    1.000762e+00  1.000762e+00   1.000762e+00     1.000762e+00
# min   -4.353568e+00 -1.608051e+00  -1.388368e+00    -1.390970e+00
# 25%   -6.212673e-01 -6.528610e-01  -7.419222e-01    -7.412846e-01
# 50%    7.207310e-02  2.159900e-02  -6.563987e-02    -6.161393e-02
# 75%    6.021990e-01  6.090091e-01   5.385387e-01     5.405942e-01
# max    3.224769e+00  3.483072e+00   5.580820e+00     5.613136e+00
#
#        TotalActiveDistance    TotalSteps  AverageActiveMinutes  \
# count         6.570000e+02  6.570000e+02          6.570000e+02
# mean         -7.435284e-17 -2.365772e-17          2.298179e-16
# std           1.000762e+00  1.000762e+00          1.000762e+00
# min          -1.373895e+00 -1.490262e+00         -1.887682e+00
# 25%          -7.426913e-01 -7.636029e-01         -6.498846e-01
# 50%          -6.178592e-02 -3.962784e-02          1.918178e-01
# 75%           5.470527e-01  6.174332e-01          7.364488e-01
# max           5.589231e+00  5.415685e+00          2.395098e+00
#
#        TotalActiveMinutes  DistanceIntensity  ActivityRank  VeryActiveMinutes  \
# count        6.570000e+02       6.570000e+02  6.570000e+02       6.570000e+02
# mean        -1.054458e-16      -1.351870e-16  1.108533e-16      -2.703739e-18
# std          1.000762e+00       1.000762e+00  1.000762e+00       1.000762e+00
# min         -1.887682e+00      -9.830852e-01 -3.052330e+00      -6.561679e-01
# 25%         -6.498846e-01      -6.733760e-01 -6.378247e-01      -6.561679e-01
# 50%          1.918178e-01      -2.667510e-01 -1.012679e-01      -5.098729e-01
# 75%          7.364488e-01       3.768964e-01  9.718456e-01       3.093796e-01
# max          2.395098e+00       7.028271e+00  1.508402e+00       5.488225e+00
#
#         AveragePace   ActiveGroup  VeryActiveRatio  VeryActiveDistance
# count  6.570000e+02  6.570000e+02     6.570000e+02        6.570000e+02
# mean   2.703739e-17 -5.407479e-18     7.570471e-17       -7.029723e-17
# std    1.000762e+00  1.000762e+00     1.000762e+00        1.000762e+00
# min   -1.707441e+00 -1.144195e+00    -6.212436e-01       -5.741406e-01
# 25%   -6.033349e-01 -1.144195e+00    -6.212436e-01       -5.741406e-01
# 50%   -6.242763e-02  2.151831e-01    -4.886785e-01       -4.563259e-01
# 75%    4.551091e-01  8.948719e-01     3.067125e-01        1.934397e-01
# max    6.846764e+00  1.574561e+00     7.323208e+00        7.251608e+00

# %% [markdown]
# # Evaluation Function

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
from sklearn.model_selection import KFold

def evaluate_model(model, model_name):
    start_time = time.time()
    
    # Inisialisasi K-Fold
    kf = KFold(n_splits=3, shuffle=True, random_state=42)
    
    rmse_train_list = []
    r2_train_list = []
    mae_train_list = []
    mape_train_list = []
    
    # K-Fold Cross Validation
    for train_index, val_index in kf.split(X_train):
        X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
        
        # Latih model pada lipatan
        model.fit(X_train_fold, y_train_fold)
        y_train_pred = model.predict(X_train_fold)
        y_val_pred = model.predict(X_val_fold)
        
        # Hitung metrik untuk lipatan
        rmse_train_list.append(np.sqrt(mean_squared_error(y_train_fold, y_train_pred)))
        r2_train_list.append(r2_score(y_train_fold, y_train_pred))
        mae_train_list.append(mean_absolute_error(y_train_fold, y_train_pred))
        mape_train_list.append(mean_absolute_percentage_error(y_train_fold, y_train_pred))

    # Rata-rata metrik untuk data latih
    rmse_train = np.mean(rmse_train_list)
    r2_train = np.mean(r2_train_list)
    mae_train = np.mean(mae_train_list)
    mape_train = np.mean(mape_train_list)

    # Latih model dengan semua data latih untuk evaluasi
    model.fit(X_train, y_train)
    
    # Hitung prediksi untuk data uji
    y_test_pred = model.predict(X_test)
    
    # Hitung metrik untuk data uji
    rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))
    r2_test = r2_score(y_test, y_test_pred)
    mae_test = mean_absolute_error(y_test, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

    # Hitung residual untuk data latih dan data uji
    y_train_pred = model.predict(X_train)  # Prediksi pada seluruh data latih
    residuals_train = y_train - y_train_pred
    residuals_test = y_test - y_test_pred
    mean_residual_train = np.mean(residuals_train)
    mean_residual_test = np.mean(residuals_test)

    # Plot residual
    plt.figure(figsize=(14, 6))

    # Plot residual dan nilai aktual vs prediksi
    plt.figure(figsize=(20, 6))

    # Residuals vs Predicted Values (data latih)
    plt.subplot(1, 3, 1)
    plt.scatter(y_train_pred, residuals_train, color='orange', alpha=0.5)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.title('Residuals vs Predicted Values (Train)')
    plt.xlabel('Predicted Values (Train)')
    plt.ylabel('Residuals (Train)')
    
    # Residuals vs Predicted Values (data uji)
    plt.subplot(1, 3, 2)
    plt.scatter(y_test_pred, residuals_test, color='blue', alpha=0.5)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.title('Residuals vs Predicted Values (Test)')
    plt.xlabel('Predicted Values (Test)')
    plt.ylabel('Residuals (Test)')
    
    # Actual vs Predicted Values (data uji)
    plt.subplot(1, 3, 3)
    plt.scatter(y_test, y_test_pred, color='green', alpha=0.5)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # Garis diagonal
    plt.title('Actual vs Predicted Values (Test)')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')

    plt.tight_layout()
    plt.show()

    end_time = time.time()
    training_time = end_time - start_time

    return {
        'Model': model_name,
        'Training Time (s)': training_time,
        'RMSE Train': rmse_train,
        'RMSE Test': rmse_test,
        'R2 Train': r2_train,
        'R2 Test': r2_test,
        'MAE Train': mae_train,
        'MAE Test': mae_test,
        'Mean Residual Train': mean_residual_train,
        'Mean Residual Test': mean_residual_test,
        'MAPE Train': mape_train,
        'MAPE Test': mape_test
    }

results = []

# %% [markdown]
# # Baseline Modelling

# %% [markdown]
# ## Linear Regression

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression

# Inisialisasi model
model = LinearRegression()

# Evaluasi model
result = evaluate_model(model, "Linear Regression")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Linear Regression', 'Training Time (s)': 0.6291694641113281, 'RMSE Train': 0.44585401892866106, 'RMSE Test': 0.5190241520379651, 'R2 Train': 0.8001326603158406, 'R2 Test': 0.7268472372381267, 'MAE Train': 0.3503652910051735, 'MAE Test': 0.39500401032688615, 'Mean Residual Train': -2.0278046111875004e-18, 'Mean Residual Test': -0.03500854570092012, 'MAPE Train': 1.123088483815743, 'MAPE Test': 1.1323137431888373}

# %% [markdown]
# ## Ridge Regression

# %%
# Ridge Regression
from sklearn.linear_model import Ridge

# Inisialisasi model Ridge Regression
model = Ridge()

# Evaluasi model
result = evaluate_model(model, "Ridge Regression")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Ridge Regression', 'Training Time (s)': 0.6075925827026367, 'RMSE Train': 0.4557041064891368, 'RMSE Test': 0.5159079797441981, 'R2 Train': 0.7911687093636249, 'R2 Test': 0.7301173580303952, 'MAE Train': 0.36495064964142626, 'MAE Test': 0.39540746772883256, 'Mean Residual Train': 0.0, 'Mean Residual Test': -0.027851115581989036, 'MAPE Train': 1.0769749025060402, 'MAPE Test': 1.0701522373519705}

# %% [markdown]
# ## Lasso Regression

# %%
# Lasso Regression
from sklearn.linear_model import Lasso

# Inisialisasi model
model = Lasso()

# Evaluasi model
result = evaluate_model(model, "Lasso Regression")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Lasso Regression', 'Training Time (s)': 0.5173876285552979, 'RMSE Train': 0.999145211687945, 'RMSE Test': 0.9932037200137604, 'R2 Train': 0.0, 'R2 Test': -0.0002467233056686613, 'MAE Train': 0.8041716576132348, 'MAE Test': 0.7971270229981045, 'Mean Residual Train': -8.111218444750002e-18, 'Mean Residual Test': -0.015598752109337205, 'MAPE Train': 1.0222531742726246, 'MAPE Test': 1.0}

# %% [markdown]
# ## Decision Tree Regressor

# %%
# Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor

# Inisialisasi model
model = DecisionTreeRegressor()

# Evaluasi model
result = evaluate_model(model, "Decision Tree Regressor")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Decision Tree Regressor', 'Training Time (s)': 0.5860791206359863, 'RMSE Train': 0.08768070147506696, 'RMSE Test': 0.6186845443878821, 'R2 Train': 0.9923046372362894, 'R2 Test': 0.6118773427824944, 'MAE Train': 0.018956674970146064, 'MAE Test': 0.4405753667763542, 'Mean Residual Train': 9.209612609143231e-18, 'Mean Residual Test': -0.03728871525132977, 'MAPE Train': 0.03294570863264166, 'MAPE Test': 1.3295531946908041}

# %% [markdown]
# ## K-Nearest Neighbor Regressor

# %%
# KNN
from sklearn.neighbors import KNeighborsRegressor

# Inisialisasi model
model = KNeighborsRegressor()

# Evaluasi model
result = evaluate_model(model, "KNN")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'KNN', 'Training Time (s)': 0.568108320236206, 'RMSE Train': 0.4880418517850466, 'RMSE Test': 0.6033960905297817, 'R2 Train': 0.7603260085508851, 'R2 Test': 0.6308223114560357, 'MAE Train': 0.36454527417446564, 'MAE Test': 0.4494247702595914, 'Mean Residual Train': 0.013235125466380886, 'Mean Residual Test': 0.0409231022063858, 'MAPE Train': 1.16667699762253, 'MAPE Test': 1.1284857781911655}

# %% [markdown]
# ## Support Vector Regressor

# %%
# SVR
from sklearn.svm import SVR

# Inisialisasi model
model = SVR()

# Evaluasi model
result = evaluate_model(model, "SVR")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'SVR', 'Training Time (s)': 0.7915525436401367, 'RMSE Train': 0.5042735100559843, 'RMSE Test': 0.5654502700101468, 'R2 Train': 0.7446444079496795, 'R2 Test': 0.6757953094414773, 'MAE Train': 0.3540682319661282, 'MAE Test': 0.3937649869380114, 'Mean Residual Train': -0.012941762634745405, 'Mean Residual Test': 0.010356872021317782, 'MAPE Train': 1.07378894897321, 'MAPE Test': 0.9475673940446109}

# %% [markdown]
# ## Random Forest Regressor

# %%
# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# Inisialisasi model
model = RandomForestRegressor()

# Evaluasi model
result = evaluate_model(model, "Random Forest Regressor")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Random Forest Regressor', 'Training Time (s)': 2.6842188835144043, 'RMSE Train': 0.2304018930952506, 'RMSE Test': 0.5074252586473876, 'R2 Train': 0.9467865495459011, 'R2 Test': 0.7389193857283363, 'MAE Train': 0.16782093346270954, 'MAE Test': 0.3874384434578503, 'Mean Residual Train': 0.002881793829685481, 'Mean Residual Test': 0.038606674629527396, 'MAPE Train': 0.4804297272976495, 'MAPE Test': 0.9567697561906463}

# %% [markdown]
# ## Gradient Boosting Regressor

# %%
# Gradient Boosting Regressor
from sklearn.ensemble import GradientBoostingRegressor

# Inisialisasi model
model = GradientBoostingRegressor()

# Evaluasi model
result = evaluate_model(model, "Gradient Boost Regressor")
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'Gradient Boost Regressor', 'Training Time (s)': 1.7433760166168213, 'RMSE Train': 0.2949043433017259, 'RMSE Test': 0.513553862665684, 'R2 Train': 0.9123355923983203, 'R2 Test': 0.7325747179710675, 'MAE Train': 0.23758709946533182, 'MAE Test': 0.3972768509821858, 'Mean Residual Train': 1.4870567148708336e-17, 'Mean Residual Test': 0.04695989693973726, 'MAPE Train': 0.7327490499247172, 'MAPE Test': 1.0398619156189328}

# %% [markdown]
# ## Hasil setelah Baseline Modelling

# %%
results_df = pd.DataFrame(results)

results_df['RMSE Difference'] = results_df['RMSE Test'] - results_df['RMSE Train']
results_df['R2 Difference'] = results_df['R2 Test'] - results_df['R2 Train']
results_df['MAE Difference'] = results_df['MAE Test'] - results_df['MAE Train']
results_df['MAPE Difference'] = results_df['MAPE Test'] - results_df['MAPE Train']

# Menentukan urutan kolom yang diinginkan
columns_order = [
    'Model', 'Training Time (s)', 
    'RMSE Train', 'RMSE Test', 'RMSE Difference',
    'R2 Train', 'R2 Test', 'R2 Difference',
    'MAE Train', 'MAE Test', 'MAE Difference',
    'Mean Residual Train', 'Mean Residual Test',
    'MAPE Train', 'MAPE Test', 'MAPE Difference'
]

# Mengatur urutan kolom dan mengurutkan hasil berdasarkan beberapa metrik
results_df = results_df[columns_order].sort_values(
    by=['RMSE Test', 'RMSE Train', 'RMSE Difference'],
    ascending=[True, True, True]
)

# Tampilkan DataFrame hasil
results_df
# Out:
#                       Model  Training Time (s)  RMSE Train  RMSE Test  \
# 6   Random Forest Regressor           2.684219    0.230402   0.507425
# 7  Gradient Boost Regressor           1.743376    0.294904   0.513554
# 1          Ridge Regression           0.607593    0.455704   0.515908
# 0         Linear Regression           0.629169    0.445854   0.519024
# 5                       SVR           0.791553    0.504274   0.565450
# 4                       KNN           0.568108    0.488042   0.603396
# 3   Decision Tree Regressor           0.586079    0.087681   0.618685
# 2          Lasso Regression           0.517388    0.999145   0.993204
#
#    RMSE Difference  R2 Train   R2 Test  R2 Difference  MAE Train  MAE Test  \
# 6         0.277023  0.946787  0.738919      -0.207867   0.167821  0.387438
# 7         0.218650  0.912336  0.732575      -0.179761   0.237587  0.397277
# 1         0.060204  0.791169  0.730117      -0.061051   0.364951  0.395407
# 0         0.073170  0.800133  0.726847      -0.073285   0.350365  0.395004
# 5         0.061177  0.744644  0.675795      -0.068849   0.354068  0.393765
# 4         0.115354  0.760326  0.630822      -0.129504   0.364545  0.449425
# 3         0.531004  0.992305  0.611877      -0.380427   0.018957  0.440575
# 2        -0.005941  0.000000 -0.000247      -0.000247   0.804172  0.797127
#
#    MAE Difference  Mean Residual Train  Mean Residual Test  MAPE Train  \
# 6        0.219618         2.881794e-03            0.038607    0.480430
# 7        0.159690         1.487057e-17            0.046960    0.732749
# 1        0.030457         0.000000e+00           -0.027851    1.076975
# 0        0.044639        -2.027805e-18           -0.035009    1.123088
# 5        0.039697        -1.294176e-02            0.010357    1.073789
# 4        0.084879         1.323513e-02            0.040923    1.166677
# 3        0.421619         9.209613e-18           -0.037289    0.032946
# 2       -0.007045        -8.111218e-18           -0.015599    1.022253
#
#    MAPE Test  MAPE Difference
# 6   0.956770         0.476340
# 7   1.039862         0.307113
# 1   1.070152        -0.006823
# 0   1.132314         0.009225
# 5   0.947567        -0.126222
# 4   1.128486        -0.038191
# 3   1.329553         1.296607
# 2   1.000000        -0.022253

# %% [markdown]
# # Tuning Modelling

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Grid Search

# %%
# Random Forest with Tuning dengan Grid Search
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Set Hyperparameter
rf_params = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2',None]
}
# Inisialisasi Model dengan Tuning
rf_model = GridSearchCV(RandomForestRegressor(), rf_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_jobs=-1)
rf_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(rf_model.best_estimator_, 'Random Forest Grid Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# {'Model': 'Random Forest Grid Search', 'Training Time (s)': 3.2723922729492188, 'RMSE Train': 0.22316911367639616, 'RMSE Test': 0.5105751989594562, 'R2 Train': 0.9499359112279983, 'R2 Test': 0.7356679081764725, 'MAE Train': 0.1664082528485121, 'MAE Test': 0.38830646383196493, 'Mean Residual Train': 0.007746795902366972, 'Mean Residual Test': 0.037700031117994644, 'MAPE Train': 0.4790773482278741, 'MAPE Test': 0.9452397869586242}

# %% [markdown]
# ### Bayesian Optimization

# %%
# Random Forest with Tuning dengan Bayesian Optimization
from skopt import BayesSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Set Hyperparameter
rf_params = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2',None]
}
# Inisialisasi Model dengan Tuning
rf_model = BayesSearchCV(RandomForestRegressor(), rf_params, scoring='neg_mean_absolute_error', cv=5, n_iter=30,verbose=2, n_jobs=-1)
rf_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(rf_model.best_estimator_, 'Random Forest Bayes Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# {'Model': 'Random Forest Bayes Search', 'Training Time (s)': 2.998816728591919, 'RMSE Train': 0.22760738026461833, 'RMSE Test': 0.5092491244714278, 'R2 Train': 0.9479910476637247, 'R2 Test': 0.7370391806181402, 'MAE Train': 0.169510443920132, 'MAE Test': 0.39223190405560787, 'Mean Residual Train': 0.004145175689662185, 'Mean Residual Test': 0.038077126440295456, 'MAPE Train': 0.49299194782913913, 'MAPE Test': 0.958244828696831}

# %% [markdown]
# ## Gradient Boost Regressor

# %% [markdown]
# ### Grid Search

# %%
# Gradient Boost with Tuning dengan Grid Search
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

# Set Hyperparameter
gb_params = {
    'n_estimators': [100, 200], 
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5]
}
# Inisialisasi Model dengan Tuning
gb_model = GridSearchCV(GradientBoostingRegressor(), gb_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_jobs=-1)
gb_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(gb_model.best_estimator_, 'Gradient Boost Grid Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# {'Model': 'Gradient Boost Grid Search', 'Training Time (s)': 2.0468385219573975, 'RMSE Train': 0.133927184924999, 'RMSE Test': 0.49168557665056406, 'R2 Train': 0.9820094813848673, 'R2 Test': 0.7548649570669421, 'MAE Train': 0.09452684822175601, 'MAE Test': 0.3655643372436958, 'Mean Residual Train': -1.6898371759895837e-17, 'Mean Residual Test': 0.03064838819447944, 'MAPE Train': 0.31356794285232586, 'MAPE Test': 1.06068989942765}

# %% [markdown]
# ### Bayesian Optimization

# %%
# Gradient Boost with Tuning dengan Bayesian Optimization
from skopt import BayesSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Set Hyperparameter
gb_params = {
    'n_estimators': [100, 200], 
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5]
}
# Inisialisasi Model dengan Tuning
gb_model = BayesSearchCV(GradientBoostingRegressor(), gb_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_iter=30, n_jobs=-1)
gb_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(rf_model.best_estimator_, 'Gradient Boost Bayes Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# {'Model': 'Gradient Boost Bayes Search', 'Training Time (s)': 3.0996387004852295, 'RMSE Train': 0.22488059808019487, 'RMSE Test': 0.5131598361739119, 'R2 Train': 0.9491077745998512, 'R2 Test': 0.7329849270242177, 'MAE Train': 0.16706046411951667, 'MAE Test': 0.39004942923318153, 'Mean Residual Train': 0.004340666557848714, 'Mean Residual Test': 0.0378354501370045, 'MAPE Train': 0.49148970991140456, 'MAPE Test': 0.9415514662862645}

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# ### Grid Search

# %%
# Ridge Regression with Tuning dengan Grid Search
from sklearn.linear_model import Ridge

# Set Hyperparameter
ridge_params = {
    'alpha': [0.1, 1.0, 10.0],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'saga'] 
}

# Inisialisasi Model dengan Tuning
ridge_model = GridSearchCV(Ridge(), ridge_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_jobs=-1)
ridge_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(ridge_model.best_estimator_, 'Ridge Grid Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# {'Model': 'Ridge Grid Search', 'Training Time (s)': 0.7445132732391357, 'RMSE Train': 0.4462227956489569, 'RMSE Test': 0.5179936280535803, 'R2 Train': 0.7997934622329351, 'R2 Test': 0.727930851641196, 'MAE Train': 0.352021288613863, 'MAE Test': 0.3948105117233514, 'Mean Residual Train': 1.128811233561042e-16, 'Mean Residual Test': -0.03435621681923448, 'MAPE Train': 1.1173201831011632, 'MAPE Test': 1.1236961589559955}

# %% [markdown]
# ### Bayesian Optimization

# %%
# Ridge Regression with Tuning dengan Bayesian Optimization
from skopt import BayesSearchCV
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error

# Set Hyperparameter
ridge_params = {
    'alpha': [0.1, 1.0, 10.0],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'saga'] 
}

# Inisialisasi Model dengan Tuning
ridge_model = BayesSearchCV(Ridge(), ridge_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_iter= 30, n_jobs=-1)
ridge_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(rf_model.best_estimator_, 'Ridge Bayes Search')
results.append(result)

# Melihat Hasil Evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [10.0, 'auto'] before, using random point [1.0, 'lsqr']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [10.0, 'cholesky']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [10.0, 'saga']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [1.0, 'lsqr'] before, using random point [0.1, 'svd']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [1.0, 'svd'] before, using random point [1.0, 'auto']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [1.0, 'lsqr'] before, using random point [1.0, 'saga']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [0.1, 'auto']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [1.0, 'lsqr'] before, using random point [1.0, 'auto']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'svd'] before, using random point [1.0, 'cholesky']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [0.1, 'lsqr']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [1.0, 'lsqr'] before, using random point [1.0, 'saga']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'cholesky'] before, using random point [0.1, 'svd']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'cholesky'] before, using random point [10.0, 'lsqr']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [0.1, 'auto']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [1.0, 'auto']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\optimizer\optimizer.py:517: UserWarning: The objective has been evaluated at point [0.1, 'lsqr'] before, using random point [1.0, 'lsqr']
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# {'Model': 'Ridge Bayes Search', 'Training Time (s)': 3.817099094390869, 'RMSE Train': 0.2256624386135192, 'RMSE Test': 0.5076463440523756, 'R2 Train': 0.9488494720422075, 'R2 Test': 0.7386918302926778, 'MAE Train': 0.16656544486303732, 'MAE Test': 0.3852272883604188, 'Mean Residual Train': -0.0016795028835184965, 'Mean Residual Test': 0.036906331347019955, 'MAPE Train': 0.49900312890182724, 'MAPE Test': 0.9927890264552621}

# %% [markdown]
# ## CatBoost

# %% [markdown]
# ### GridSearch

# %%
# CatBoost with Tuning dengan GridSearch
from catboost import CatBoostRegressor
from sklearn.model_selection import GridSearchCV

# Set Hyperparameter
cat_params = {
    'depth': [None, 6, 8], 
    'iterations': [100, 200],
    'learning_rate': [0.01, 0.1],
    'l2_leaf_reg': [3, 5] 
}

# Inisialisasi model dengan Tuning
cat_model = GridSearchCV(CatBoostRegressor(silent=True), cat_params, scoring='neg_mean_absolute_error', cv=5, verbose=2, n_jobs=-1)
cat_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(cat_model.best_estimator_, 'CatBoost GridSearch')
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# {'Model': 'CatBoost GridSearch', 'Training Time (s)': 4.2321062088012695, 'RMSE Train': 0.25109306042956164, 'RMSE Test': 0.49794352424600574, 'R2 Train': 0.9363226075613141, 'R2 Test': 0.748585315696638, 'MAE Train': 0.20084824765183473, 'MAE Test': 0.3824086727649981, 'Mean Residual Train': -0.00025392924082443067, 'Mean Residual Test': 0.04359918115097025, 'MAPE Train': 0.6504086868032565, 'MAPE Test': 0.9833964817273392}

# %% [markdown]
# ### Bayesian Optimization

# %%
# Set Hyperparameter
cat_params = {
    'depth': [None, 6, 8], 
    'iterations': [100, 200],
    'learning_rate': [0.01, 0.1],
    'l2_leaf_reg': [3, 5] 
}

# Inisialisasi model dengan Tuning
cat_model = BayesSearchCV(CatBoostRegressor(silent=True), cat_params, scoring='neg_mean_absolute_error', cv=5,n_iter=30, verbose=2, n_jobs=-1)
cat_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(cat_model.best_estimator_, 'CatBoost BayesSearch')
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [100, 200] was inferred to Integer(low=100, high=200, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(100, 200), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.01, 0.1] was inferred to Real(low=0.01, high=0.1, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.01, 0.1), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# {'Model': 'CatBoost BayesSearch', 'Training Time (s)': 3.497342824935913, 'RMSE Train': 0.25109306042956164, 'RMSE Test': 0.49794352424600574, 'R2 Train': 0.9363226075613141, 'R2 Test': 0.748585315696638, 'MAE Train': 0.20084824765183473, 'MAE Test': 0.3824086727649981, 'Mean Residual Train': -0.00025392924082443067, 'Mean Residual Test': 0.04359918115097025, 'MAPE Train': 0.6504086868032565, 'MAPE Test': 0.9833964817273392}

# %% [markdown]
# ## XG Boost

# %% [markdown]
# ### GridSearch

# %%
# XG Boost with Tuning dengan GridSearch
import xgboost as xgb
from xgboost import XGBRegressor


# Set Hyperparameter
xgb_params = { 'n_estimators': [50, 100],        
    'max_depth': [3, 5],               
    'learning_rate': [0.01, 0.1, 0.2], 
    'subsample': [0.8, 1.0] 
    }

# Inisialisasi Model 
xgb_model = GridSearchCV(XGBRegressor(), xgb_params, scoring='neg_mean_absolute_error',cv=5)
xgb_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(xgb_model.best_estimator_, 'XG Boost GridSearch')
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# {'Model': 'XG Boost GridSearch', 'Training Time (s)': 1.9707815647125244, 'RMSE Train': 0.1050438816804581, 'RMSE Test': 0.48438640849379955, 'R2 Train': 0.9889329143408377, 'R2 Test': 0.7620890891735774, 'MAE Train': 0.060070045934367905, 'MAE Test': 0.3617159349954163, 'Mean Residual Train': 0.0010037220818881305, 'Mean Residual Test': 0.03202624944360705, 'MAPE Train': 0.18138373322689672, 'MAPE Test': 1.0583306740198544}

# %% [markdown]
# ### Bayesian Optimization

# %%
# XG Boost with Tuning dengan GridSearch
import xgboost as xgb
from xgboost import XGBRegressor

# Set Hyperparameter
xgb_params = { 'n_estimators': [50, 100],        
    'max_depth': [3, 5],               
    'learning_rate': [0.01, 0.1, 0.2], 
    'subsample': [0.8, 1.0] 
    }

# Inisialisasi Model 
xgb_model = BayesSearchCV(XGBRegressor(), xgb_params, scoring='neg_mean_absolute_error',n_iter=30,cv=5)
xgb_model.fit(X_train, y_train)

# Evaluasi Model
result = evaluate_model(xgb_model.best_estimator_, 'XG Boost BayesSearch')
results.append(result)

# Melihat hasil evaluasi
print(result)
# Out:
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [50, 100] was inferred to Integer(low=50, high=100, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(50, 100), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.8, 1.0] was inferred to Real(low=0.8, high=1.0, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.8, 1.0), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [50, 100] was inferred to Integer(low=50, high=100, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(50, 100), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.8, 1.0] was inferred to Real(low=0.8, high=1.0, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.8, 1.0), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [50, 100] was inferred to Integer(low=50, high=100, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(50, 100), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# c:\Users\putri\anaconda3\Lib\site-packages\skopt\space\space.py:116: UserWarning: Dimension [0.8, 1.0] was inferred to Real(low=0.8, high=1.0, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(0.8, 1.0), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# {'Model': 'XG Boost BayesSearch', 'Training Time (s)': 1.5615735054016113, 'RMSE Train': 0.14634103493939318, 'RMSE Test': 0.5068139478355262, 'R2 Train': 0.9784962534650531, 'R2 Test': 0.7395480704900623, 'MAE Train': 0.10557833318748071, 'MAE Test': 0.37319149808707547, 'Mean Residual Train': -0.0001925507108884561, 'Mean Residual Test': 0.03838732495545657, 'MAPE Train': 0.35848607759690226, 'MAPE Test': 1.0594587359547827}

# %% [markdown]
# ## Hasil Setelah Tuning Modelling

# %%
results_df = pd.DataFrame(results)

results_df['RMSE Difference'] = results_df['RMSE Test'] - results_df['RMSE Train']
results_df['R2 Difference'] = results_df['R2 Test'] - results_df['R2 Train']
results_df['MAE Difference'] = results_df['MAE Test'] - results_df['MAE Train']
results_df['MAPE Difference'] = results_df['MAPE Test'] - results_df['MAPE Train']

results_df = results_df[columns_order].sort_values(by=['RMSE Test','RMSE Train','RMSE Difference'],ascending=[True,True,True])

results_df
# Out:
#                           Model  Training Time (s)  RMSE Train  RMSE Test  \
# 16          XG Boost GridSearch           1.970782    0.105044   0.484386
# 10   Gradient Boost Grid Search           2.046839    0.133927   0.491686
# 14          CatBoost GridSearch           4.232106    0.251093   0.497944
# 15         CatBoost BayesSearch           3.497343    0.251093   0.497944
# 17         XG Boost BayesSearch           1.561574    0.146341   0.506814
# 6       Random Forest Regressor           2.684219    0.230402   0.507425
# 13           Ridge Bayes Search           3.817099    0.225662   0.507646
# 9    Random Forest Bayes Search           2.998817    0.227607   0.509249
# 8     Random Forest Grid Search           3.272392    0.223169   0.510575
# 11  Gradient Boost Bayes Search           3.099639    0.224881   0.513160
# 7      Gradient Boost Regressor           1.743376    0.294904   0.513554
# 1              Ridge Regression           0.607593    0.455704   0.515908
# 12            Ridge Grid Search           0.744513    0.446223   0.517994
# 0             Linear Regression           0.629169    0.445854   0.519024
# 5                           SVR           0.791553    0.504274   0.565450
# 4                           KNN           0.568108    0.488042   0.603396
# 3       Decision Tree Regressor           0.586079    0.087681   0.618685
# 2              Lasso Regression           0.517388    0.999145   0.993204
#
#     RMSE Difference  R2 Train   R2 Test  R2 Difference  MAE Train  MAE Test  \
# 16         0.379343  0.988933  0.762089      -0.226844   0.060070  0.361716
# 10         0.357758  0.982009  0.754865      -0.227145   0.094527  0.365564
# 14         0.246850  0.936323  0.748585      -0.187737   0.200848  0.382409
# 15         0.246850  0.936323  0.748585      -0.187737   0.200848  0.382409
# 17         0.360473  0.978496  0.739548      -0.238948   0.105578  0.373191
# 6          0.277023  0.946787  0.738919      -0.207867   0.167821  0.387438
# 13         0.281984  0.948849  0.738692      -0.210158   0.166565  0.385227
# 9          0.281642  0.947991  0.737039      -0.210952   0.169510  0.392232
# 8          0.287406  0.949936  0.735668      -0.214268   0.166408  0.388306
# 11         0.288279  0.949108  0.732985      -0.216123   0.167060  0.390049
# 7          0.218650  0.912336  0.732575      -0.179761   0.237587  0.397277
# 1          0.060204  0.791169  0.730117      -0.061051   0.364951  0.395407
# 12         0.071771  0.799793  0.727931      -0.071863   0.352021  0.394811
# 0          0.073170  0.800133  0.726847      -0.073285   0.350365  0.395004
# 5          0.061177  0.744644  0.675795      -0.068849   0.354068  0.393765
# 4          0.115354  0.760326  0.630822      -0.129504   0.364545  0.449425
# 3          0.531004  0.992305  0.611877      -0.380427   0.018957  0.440575
# 2         -0.005941  0.000000 -0.000247      -0.000247   0.804172  0.797127
#
#     MAE Difference  Mean Residual Train  Mean Residual Test  MAPE Train  \
# 16        0.301646         1.003722e-03            0.032026    0.181384
# 10        0.271037        -1.689837e-17            0.030648    0.313568
# 14        0.181560        -2.539292e-04            0.043599    0.650409
# 15        0.181560        -2.539292e-04            0.043599    0.650409
# 17        0.267613        -1.925507e-04            0.038387    0.358486
# 6         0.219618         2.881794e-03            0.038607    0.480430
# 13        0.218662        -1.679503e-03            0.036906    0.499003
# 9         0.222721         4.145176e-03            0.038077    0.492992
# 8         0.221898         7.746796e-03            0.037700    0.479077
# 11        0.222989         4.340667e-03            0.037835    0.491490
# 7         0.159690         1.487057e-17            0.046960    0.732749
# 1         0.030457         0.000000e+00           -0.027851    1.076975
# 12        0.042789         1.128811e-16           -0.034356    1.117320
# 0         0.044639        -2.027805e-18           -0.035009    1.123088
# 5         0.039697        -1.294176e-02            0.010357    1.073789
# 4         0.084879         1.323513e-02            0.040923    1.166677
# 3         0.421619         9.209613e-18           -0.037289    0.032946
# 2        -0.007045        -8.111218e-18           -0.015599    1.022253
#
#     MAPE Test  MAPE Difference
# 16   1.058331         0.876947
# 10   1.060690         0.747122
# 14   0.983396         0.332988
# 15   0.983396         0.332988
# 17   1.059459         0.700973
# 6    0.956770         0.476340
# 13   0.992789         0.493786
# 9    0.958245         0.465253
# 8    0.945240         0.466162
# 11   0.941551         0.450062
# 7    1.039862         0.307113
# 1    1.070152        -0.006823
# 12   1.123696         0.006376
# 0    1.132314         0.009225
# 5    0.947567        -0.126222
# 4    1.128486        -0.038191
# 3    1.329553         1.296607
# 2    1.000000        -0.022253
